# %%
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import pairwise_distances
import importlib, sys

# %%
parentdir = 'C:\\Users\\danie\\Documents\\work\\testingRS\\TESTS'
sys.path.insert(0,parentdir) 
import entity
importlib.reload(entity)
from entity import CF, User

# %%
with open('C:\\Users\\danie\\Documents\\work\\testingRS\\TESTS\\objects\\subset_1000.pkl', 'rb') as f:
    utility_matrix_1, interactions_work_1 = pickle.load(f)

# %%
USER = '-3596626804281480007' # USER = '-1032019229384696495' MUY ACTIVO
user_object = User(USER, utility_matrix_1, interactions_work_1)
cf = CF(user_object)
cf_predictions = cf.predict_ratings(NUMBER_NEIGHBORS, USER, cf.user.utility_matrix, cf.user.items_to_ignore)

# %%
cf_predictions
# Out:
#                       -1021685224930603833  -1591454024897803197  \
# -3596626804281480007              0.044464              0.044464
#
#                       -1672166631728511207  -1802980374508081539  \
# -3596626804281480007              0.428557              0.044464
#
#                       -2081760549863309770  -2176468683077766369  \
# -3596626804281480007              0.044464              0.574412
#
#                       -2271868873349907631  -2711301039947937868  \
# -3596626804281480007              0.044464              0.044464
#
#                       -2778760500673113802  -2826566343807132236  ...  \
# -3596626804281480007              0.044464              0.044464  ...
#
#                       8095004770374551394  809601605585939618  \
# -3596626804281480007             0.044464            0.044464
#
#                       8194079557551008273  8219310215587599928  \
# -3596626804281480007             0.044464             0.044464
#
# ...

# %%
u,s,i = cf.getNneighbors(NUMBER_NEIGHBORS, USER, cf.user.utility_matrix)
cf.CalculatePrediction(NUMBER_NEIGHBORS, USER, '-1591454024897803197',  cf.user.utility_matrix)
# Out:
# 0.044463959139348225

# %%
ITEM = '-1802980374508081539'
u, similarities, indices = cf.getNneighbors(10, '-3596626804281480007', cf.user.utility_matrix)
sum_n_similarities = np.sum(similarities)
index_user = list(utility_matrix_1.index).index(USER)
mean_rating_user= utility_matrix_1.iloc[index_user, :].mean()
wtd_sum = 0
for index,i in enumerate(indices):
    user_neig= list(utility_matrix_1.index)[i]  #neighbor id
    print('user')
    rating_neig = utility_matrix_1.loc[user_neig][ITEM]   #user rating for the item
    average_neig = np.mean(utility_matrix_1.iloc[i,:])  #user average rating
    print(average_neig)
    rating_diff = rating_neig - average_neig
    product = rating_diff * (similarities[index])
    wtd_sum = wtd_sum + product
    #print(wtd_sum)

prediction = mean_rating_user + (wtd_sum/sum_n_similarities)
print("PREDICTION")
print(prediction)
# Out:
# user
# 0.07751937984496124
# -0.07751937984496124
# user
# 0.031007751937984496
# -0.031007751937984496
# user
# 0.29457364341085274
# -0.29457364341085274
# user
# 0.08527131782945736
# -0.08527131782945736
# user
# 0.08527131782945736
# -0.08527131782945736
# user
# 0.015503875968992248
# -0.015503875968992248
# user
# 0.031007751937984496
# -0.031007751937984496
# user
# 0.12403100775193798
# -0.12403100775193798
# user
# 0.12403100775193798
# -0.12403100775193798
# user
# 0.08527131782945736
# -0.08527131782945736
# PREDICTION
# 0.044463959139348225

# %%
utility_matrix_1.iloc[152,:]
# Out:
# contentId
# -1021685224930603833    0.0
# -1039912738963181810    0.0
# -1590585250246572231    2.0
# -1591454024897803197    0.0
# -1662763254714212341    0.0
#                        ...
# 8545647269051113523     0.0
# 8565115980515859979     0.0
# 8742078838645536785     2.0
# 9032993320407723266     0.0
# 9122627895188486603     0.0
# Name: 3429602690322213789, Length: 129, dtype: float64

# %%
utility_matrix_1
# Out:
# contentId             -1021685224930603833  -1039912738963181810  \
# personId
# -1032019229384696495                   0.0                   2.0
# -108842214936804958                    0.0                   0.0
# -123314413156450014                    0.0                   0.0
# -1352542225971050638                   0.0                   0.0
# -1387464358334758758                   0.0                   0.0
# ...                                    ...                   ...
# 9038446466275805109                    0.0                   0.0
# 9050204922960952289                    0.0                   0.0
# 9135582630122950040                    0.0                   0.0
# 9137372837662939523                    0.0                   0.0
# 9210530975708218054                    0.0                   0.0
#
# contentId             -1590585250246572231  -1591454024897803197  \
# personId
# -1032019229384696495                   2.0                   0.0
# ...

# %%
# for i,indice in enumerate(indices):
#     print('{} Similarity - {}'.format(list(utility_matrix_1.index)[indice], similarities[i]))


# sims =  pd.DataFrame(cosine_similarity(utility_matrix_1))
