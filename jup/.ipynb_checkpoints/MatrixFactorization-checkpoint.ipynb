# %%
import pandas as pd
import pickle
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
import numpy as np
import sys

# %%
parentdir = 'C:\\Users\\danie\\Documents\\work\\testingRS\\TESTS'
sys.path.insert(0,parentdir) 
from entity import User, MF

# %%
with open('C:\\Users\\danie\\Documents\\work\\testingRS\\TESTS\\objects\\subset_1000.pkl', 'rb') as f:  
    utility_matrix_1, interactions_work_1 = pickle.load(f)

# %%
NUMBER_OF_FACTORS_MF = 15
USER = '-3596626804281480007'
user_object = User(USER, utility_matrix_1, interactions_work_1)
mf = MF(user_object)
mf_predctions = mf.predict_matrix(mf.user.utility_matrix, FACTORS_MF)
results_MF = mf.remove_items(FACTORS_MF)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-395886a70b4b> in <module>
#       1 NUMBER_OF_FACTORS_MF = 15
#       2 USER = '-3596626804281480007'
# ----> 3 mf = MF(user_object)
#       4 mf_predctions = mf.predict_matrix(mf.user.utility_matrix, FACTORS_MF)
#       5 results_MF = mf.remove_items(FACTORS_MF)
#
# NameError: name 'user_object' is not defined

# %%
df = predict_matrix(utility_matrix_1, 15)

item_ids = list(utility_matrix_1.columns)
item_ids[10]
# Out:
# C:\Users\danie\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# '-2711301039947937868'

# %%
USER = '-1352542225971050638'
items_to_ignore = interactions_work_1[interactions_work_1['personId'] == USER].contentId.unique()

ds = df.loc[USER, [it for it in item_ids if it not in items_to_ignore]].to_frame().T
df
# Out:
# contentId             -1021685224930603833  -1039912738963181810  \
# -1032019229384696495              0.150315              0.471570
# -108842214936804958               0.163868              0.175577
# -123314413156450014               0.154530              0.124931
# -1352542225971050638              0.165235              0.161791
# -1387464358334758758              0.149783              0.173945
# ...                                    ...                   ...
# 9038446466275805109               0.161960              0.162687
# 9050204922960952289               0.153415              0.133354
# 9135582630122950040               0.161111              0.123106
# 9137372837662939523               0.164691              0.163625
# 9210530975708218054               0.158805              0.169014
#
# contentId             -1590585250246572231  -1591454024897803197  \
# -1032019229384696495              0.488330              0.156968
# ...

# %%
ds
# Out:
# contentId             -1021685224930603833  -1039912738963181810  \
# -1352542225971050638              0.165235              0.161791
#
# contentId             -1590585250246572231  -1591454024897803197  \
# -1352542225971050638              0.160041              0.158654
#
# contentId             -1662763254714212341  -1672166631728511207  \
# -1352542225971050638              0.156752              0.163965
#
# contentId             -1802980374508081539  -2081760549863309770  \
# -1352542225971050638              0.156814              0.161931
#
# contentId             -2176468683077766369  -2271868873349907631  ...  \
# -1352542225971050638              0.163173              0.158343  ...
#
# contentId             8194079557551008273  8219310215587599928  \
# -1352542225971050638             0.164303             0.157726
#
# contentId             8298709454703868984  84318068629167514  \
# -1352542225971050638             0.159441           0.158638
#
# ...
